# %%
import pandas as pd
import os

# %%
# Read the CSV file
Main_df = pd.read_csv("Resources/2018data.csv")
#Kaggle site: https://www.kaggle.com/datasets/yuanyuwendymu/airline-delay-and-cancellation-data-2009-2018?select=2018.csv - 0.5% sample

Main_df=pd.DataFrame(Main_df)

# Display the first few rows
Main_df.head(100)
# Out:
#        FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0   2018-11-09         DL               2602    ATL  MDT          2132
# 1   2018-06-05         HA                202    HNL  ITO           615
# 2   2018-11-11         MQ               3317    DFW  LIT          1355
# 3   2018-11-30         AS                112    ANC  SEA           800
# 4   2018-03-19         OO               4822    MSP  BIS          1125
# ..         ...        ...                ...    ...  ...           ...
# 95  2018-04-30         WN                542    BWI  MDW          1525
# 96  2018-10-02         AS                403    LAX  SEA           600
# 97  2018-08-13         AA               1859    DFW  PHL          1015
# 98  2018-06-24         DL                890    LAS  SEA          1830
# 99  2018-09-30         DL               1831    SLC  SFO          1650
#
#     DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0     2144.0       12.0      16.0      2200.0  ...             118.0
# 1      608.0       -7.0      11.0       619.0  ...              54.0
# 2     1353.0       -2.0      12.0      1405.0  ...              69.0
# 3      759.0       -1.0      20.0       819.0  ...             208.0
# 4     1121.0       -4.0      30.0      1151.0  ...              89.0
# ..       ...        ...       ...         ...  ...               ...
# 95    1530.0        5.0      12.0      1542.0  ...             120.0
# 96     552.0       -8.0      23.0       615.0  ...             174.0
# 97    1113.0       58.0      15.0      1128.0  ...             196.0
# 98    1824.0       -6.0      15.0      1839.0  ...             159.0
# 99    1648.0       -2.0      17.0      1705.0  ...             128.0
#
#     ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0                 104.0      84.0     620.0            NaN            NaN
# 1                  53.0      37.0     216.0            NaN            NaN
# 2                  59.0      43.0     304.0            NaN            NaN
# 3                 231.0     199.0    1448.0            0.0            0.0
# 4                 105.0      70.0     386.0            NaN            NaN
# ..                  ...       ...       ...            ...            ...
# 95                107.0      90.0     611.0            NaN            NaN
# 96                174.0     137.0     954.0            NaN            NaN
# 97                189.0     167.0    1303.0            8.0            0.0
# 98                157.0     128.0     867.0            NaN            NaN
# 99                120.0      91.0     599.0            NaN            NaN
#
#    NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0        NaN             NaN                  NaN          NaN
# 1        NaN             NaN                  NaN          NaN
# 2        NaN             NaN                  NaN          NaN
# 3       22.0             0.0                  0.0          NaN
# 4        NaN             NaN                  NaN          NaN
# ..       ...             ...                  ...          ...
# 95       NaN             NaN                  NaN          NaN
# 96       NaN             NaN                  NaN          NaN
# 97       0.0             0.0                 43.0          NaN
# 98       NaN             NaN                  NaN          NaN
# 99       NaN             NaN                  NaN          NaN
#
# [100 rows x 28 columns]

# %%
Main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 72134 entries, 0 to 72133
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   FL_DATE              72134 non-null  object
#  1   OP_CARRIER           72134 non-null  object
#  2   OP_CARRIER_FL_NUM    72134 non-null  int64
#  3   ORIGIN               72134 non-null  object
#  4   DEST                 72134 non-null  object
#  5   CRS_DEP_TIME         72134 non-null  int64
#  6   DEP_TIME             70974 non-null  float64
#  7   DEP_DELAY            70917 non-null  float64
#  8   TAXI_OUT             70942 non-null  float64
#  9   WHEELS_OFF           70942 non-null  float64
#  10  WHEELS_ON            70901 non-null  float64
#  11  TAXI_IN              70901 non-null  float64
#  12  CRS_ARR_TIME         72134 non-null  int64
#  13  ARR_TIME             70901 non-null  float64
#  14  ARR_DELAY            70727 non-null  float64
#  15  CANCELLED            72134 non-null  float64
#  16  CANCELLATION_CODE    1202 non-null   object
#  17  DIVERTED             72134 non-null  float64
#  18  CRS_ELAPSED_TIME     72134 non-null  float64
#  19  ACTUAL_ELAPSED_TIME  70746 non-null  float64
#  20  AIR_TIME             70746 non-null  float64
#  21  DISTANCE             72134 non-null  float64
#  22  CARRIER_DELAY        13635 non-null  float64
#  23  WEATHER_DELAY        13635 non-null  float64
#  24  NAS_DELAY            13635 non-null  float64
#  25  SECURITY_DELAY       13635 non-null  float64
#  26  LATE_AIRCRAFT_DELAY  13635 non-null  float64
#  27  Unnamed: 27          0 non-null      float64
# dtypes: float64(20), int64(3), object(5)
# memory usage: 15.4+ MB

# %%
# Get unique values from 'OP_CARRIER'
unique_values = Main_df['OP_CARRIER'].unique()

print(unique_values)
# Out:
# ['DL' 'HA' 'MQ' 'AS' 'OO' 'WN' 'YV' 'UA' 'B6' 'AA' 'EV' '9E' 'VX' 'G4'
#  'YX' 'OH' 'F9' 'NK']

# %%
# Create an Airline DataFrame using IATA Airline codes: DL = Delta, AS = Alaska , WN = Southwest
#G4 = Allegiant Air, F9 = Frontier, NK = Spirit Airlines, UA = United Airlines, B6 = JetBlue, AA = American Airlines

# Create a dictionary with IATA codes and Airlines
iata_data = {
    'IATA Code': ['DL', 'AS', 'WN', 'G4', 'F9', 'NK', 'UA', 'B6', 'AA'],
    'Airline': ['Delta Airlines', 'Alaska Airlines', 'Southwest Airlines', 'Allegiant Air', 'Frontier Airlines', 'Spirit Airlines', 'United Airlines', 'JetBlue', 'American Airlines']
}

# Create a DataFrame from the dictionary
IATA_df = pd.DataFrame(iata_data)

# Rename IATA Code Column
IATA_df.rename(columns = {'IATA Code': 'IATA_code'}, inplace=True)

# Display the DataFrame
IATA_df
# Out:
#   IATA_code             Airline
# 0        DL      Delta Airlines
# 1        AS     Alaska Airlines
# 2        WN  Southwest Airlines
# 3        G4       Allegiant Air
# 4        F9   Frontier Airlines
# 5        NK     Spirit Airlines
# 6        UA     United Airlines
# 7        B6             JetBlue
# 8        AA   American Airlines

# %%
# Export the DataFrame to a CSV file
directory = 'Resources'
file_name = 'IATA_airlines.csv'
file_path = os.path.join(directory, file_name)
IATA_df.to_csv(file_path, index=False)

# %%
#Clean the Main data to remove smaller airlines or obsolete values
# List of carriers to remove
carriers_to_remove = ['HA', 'MQ', 'OO', 'YV', 'EV', '9E', 'VX', 'YX', 'OH']

# Remove rows where 'OP_CARRIER' is in the list of carriers to remove
Main_df2 = Main_df[~Main_df['OP_CARRIER'].isin(carriers_to_remove)]

# Display the filtered DataFrame
Main_df2
# Out:
#           FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0      2018-11-09         DL               2602    ATL  MDT          2132
# 3      2018-11-30         AS                112    ANC  SEA           800
# 5      2018-08-04         WN               5855    MSY  MCO          1635
# 7      2018-03-12         AS                445    LAX  SEA          1840
# 8      2018-01-28         WN               2674    PHX  ABQ          1255
# ...           ...        ...                ...    ...  ...           ...
# 72128  2018-06-08         DL               1494    PHL  ATL          1154
# 72129  2018-11-14         B6                192    TPA  BOS           600
# 72130  2018-01-15         DL                930    DTW  MCI           825
# 72131  2018-11-02         WN               2341    ATL  LGA          1530
# 72133  2018-09-24         WN               3810    BWI  ORF          1055
#
#        DEP_TIME  DEP_DELAY  TAXI_OUT  WHEELS_OFF  ...  CRS_ELAPSED_TIME  \
# 0        2144.0       12.0      16.0      2200.0  ...             118.0
# 3         759.0       -1.0      20.0       819.0  ...             208.0
# 5        1629.0       -6.0      12.0      1641.0  ...             105.0
# 7        1854.0       14.0      36.0      1930.0  ...             172.0
# 8        1252.0       -3.0      10.0      1302.0  ...              65.0
# ...         ...        ...       ...         ...  ...               ...
# 72128    1150.0       -4.0      15.0      1205.0  ...             139.0
# 72129     547.0      -13.0      12.0       559.0  ...             172.0
# 72130     847.0       22.0      58.0       945.0  ...             142.0
# 72131    1529.0       -1.0      20.0      1549.0  ...             135.0
# 72133    1059.0        4.0      13.0      1112.0  ...              55.0
#
#        ACTUAL_ELAPSED_TIME  AIR_TIME  DISTANCE  CARRIER_DELAY  WEATHER_DELAY  \
# 0                    104.0      84.0     620.0            NaN            NaN
# 3                    231.0     199.0    1448.0            0.0            0.0
# 5                     99.0      79.0     551.0            NaN            NaN
# 7                    164.0     120.0     954.0            NaN            NaN
# 8                     63.0      50.0     328.0            NaN            NaN
# ...                    ...       ...       ...            ...            ...
# 72128                119.0      97.0     666.0            NaN            NaN
# 72129                149.0     133.0    1185.0            NaN            NaN
# 72130                161.0      98.0     629.0            0.0            0.0
# 72131                128.0     105.0     762.0            NaN            NaN
# 72133                 50.0      34.0     159.0            NaN            NaN
#
#       NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 27
# 0           NaN             NaN                  NaN          NaN
# 3          22.0             0.0                  0.0          NaN
# 5           NaN             NaN                  NaN          NaN
# 7           NaN             NaN                  NaN          NaN
# 8           NaN             NaN                  NaN          NaN
# ...         ...             ...                  ...          ...
# 72128       NaN             NaN                  NaN          NaN
# 72129       NaN             NaN                  NaN          NaN
# 72130      19.0             0.0                 22.0          NaN
# 72131       NaN             NaN                  NaN          NaN
# 72133       NaN             NaN                  NaN          NaN
#
# [47717 rows x 28 columns]

# %%
# Make sure we are down to the 9 main carriers
unique_values = Main_df2['OP_CARRIER'].unique()

print(unique_values)
# Out:
# ['DL' 'AS' 'WN' 'UA' 'B6' 'AA' 'G4' 'F9' 'NK']

# %%
# Clean the DataFrame down to only the columns we need
# Specify the columns to keep
columns_to_keep = ['FL_DATE', 'OP_CARRIER', 'OP_CARRIER_FL_NUM','ORIGIN', 'DEST', 'CRS_DEP_TIME', 'DEP_TIME', 
                   'DEP_DELAY', 'CRS_ARR_TIME', 'ARR_TIME', 'CANCELLED', 'AIR_TIME', 'DISTANCE' ]

# Create a new DataFrame with only the specified columns
Main_df3 = Main_df2[columns_to_keep]

# Display the new DataFrame
Main_df3
# Out:
#           FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0      2018-11-09         DL               2602    ATL  MDT          2132
# 3      2018-11-30         AS                112    ANC  SEA           800
# 5      2018-08-04         WN               5855    MSY  MCO          1635
# 7      2018-03-12         AS                445    LAX  SEA          1840
# 8      2018-01-28         WN               2674    PHX  ABQ          1255
# ...           ...        ...                ...    ...  ...           ...
# 72128  2018-06-08         DL               1494    PHL  ATL          1154
# 72129  2018-11-14         B6                192    TPA  BOS           600
# 72130  2018-01-15         DL                930    DTW  MCI           825
# 72131  2018-11-02         WN               2341    ATL  LGA          1530
# 72133  2018-09-24         WN               3810    BWI  ORF          1055
#
#        DEP_TIME  DEP_DELAY  CRS_ARR_TIME  ARR_TIME  CANCELLED  AIR_TIME  \
# 0        2144.0       12.0          2330    2328.0        0.0      84.0
# 3         759.0       -1.0          1228    1250.0        0.0     199.0
# 5        1629.0       -6.0          1920    1908.0        0.0      79.0
# 7        1854.0       14.0          2132    2138.0        0.0     120.0
# 8        1252.0       -3.0          1400    1355.0        0.0      50.0
# ...         ...        ...           ...       ...        ...       ...
# 72128    1150.0       -4.0          1413    1349.0        0.0      97.0
# 72129     547.0      -13.0           852     816.0        0.0     133.0
# 72130     847.0       22.0           947    1028.0        0.0      98.0
# 72131    1529.0       -1.0          1745    1737.0        0.0     105.0
# 72133    1059.0        4.0          1150    1149.0        0.0      34.0
#
#        DISTANCE
# 0         620.0
# 3        1448.0
# 5         551.0
# 7         954.0
# 8         328.0
# ...         ...
# 72128     666.0
# 72129    1185.0
# 72130     629.0
# 72131     762.0
# 72133     159.0
#
# [47717 rows x 13 columns]

# %%
Main_df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47717 entries, 0 to 72133
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   FL_DATE            47717 non-null  object
#  1   OP_CARRIER         47717 non-null  object
#  2   OP_CARRIER_FL_NUM  47717 non-null  int64
#  3   ORIGIN             47717 non-null  object
#  4   DEST               47717 non-null  object
#  5   CRS_DEP_TIME       47717 non-null  int64
#  6   DEP_TIME           47163 non-null  float64
#  7   DEP_DELAY          47163 non-null  float64
#  8   CRS_ARR_TIME       47717 non-null  int64
#  9   ARR_TIME           47127 non-null  float64
#  10  CANCELLED          47717 non-null  float64
#  11  AIR_TIME           47028 non-null  float64
#  12  DISTANCE           47717 non-null  float64
# dtypes: float64(6), int64(3), object(4)
# memory usage: 5.1+ MB

# %%
# Export the DataFrame to a CSV file
directory = 'Resources'
file_name = 'Main_flight_data.csv'
file_path = os.path.join(directory, file_name)
Main_df3.to_csv(file_path, index=False)

# %%
# Read the CSV file
Airports_df = pd.read_csv("Resources/us-airports.csv")
#site: https://data.humdata.org/dataset/ourairports-usa

Airports_df=pd.DataFrame(Airports_df)

# Display the first few rows
Airports_df
# Out:
#               id        ident                 type  \
# 0      #meta +id  #meta +code  #loc +airport +type
# 1           3632         KLAX        large_airport
# 2           3754         KORD        large_airport
# 3           3622         KJFK        large_airport
# 4           3384         KATL        large_airport
# ...          ...          ...                  ...
# 32003     342483      US-3397               closed
# 32004     322813      US-0527             heliport
# 32005     324916      US-0652             heliport
# 32006     327838      US-0874             heliport
# 32007     336215      US-1675               closed
#
#                                                    name latitude_deg  \
# 0                                   #loc +airport +name    #geo +lat
# 1                     Los Angeles International Airport    33.942501
# 2                  Chicago O'Hare International Airport      41.9786
# 3                  John F Kennedy International Airport    40.639447
# 4      Hartsfield Jackson Atlanta International Airport      33.6367
# ...                                                 ...          ...
# 32003                       Lake Mountain Landing Strip     40.02128
# 32004                 AdventHealth Zephyrhills Heliport    28.261934
# 32005                               Rotary Run Heliport    40.605805
# 32006                               Black Rock Heliport    35.084975
# 32007                                    Zzyzx Airstrip    35.143373
#
#       longitude_deg         elevation_ft                 continent  \
# 0         #geo +lon  #geo +elevation +ft  #region +continent +code
# 1       -118.407997                  125                       NaN
# 2          -87.9048                  680                       NaN
# 3        -73.779317                   13                       NaN
# 4        -84.428101                 1026                       NaN
# ...             ...                  ...                       ...
# 32003    -123.40367                 3392                       NaN
# 32004    -82.185663                  160                       NaN
# 32005    -81.415002                 1027                       NaN
# 32006    -108.78835                 6454                       NaN
# 32007   -116.107035                  NaN                       NaN
#
#          country_name           iso_country  ...   scheduled_service  \
# 0      #country +name  #country +code +iso2  ...  #status +scheduled
# 1       United States                    US  ...                   1
# 2       United States                    US  ...                   1
# 3       United States                    US  ...                   1
# 4       United States                    US  ...                   1
# ...               ...                   ...  ...                 ...
# 32003   United States                    US  ...                   0
# 32004   United States                    US  ...                   0
# 32005   United States                    US  ...                   0
# 32006   United States                    US  ...                   0
# 32007   United States                    US  ...                   0
#
#                        gps_code                  icao_code  \
# 0      #loc +airport +code +gps  #loc +airport +code +icao
# 1                          KLAX                       KLAX
# 2                          KORD                       KORD
# 3                          KJFK                       KJFK
# 4                          KATL                       KATL
# ...                         ...                        ...
# 32003                       NaN                        NaN
# 32004                      FD75                        NaN
# 32005                       NaN                        NaN
# 32006                       NaN                        NaN
# 32007                       NaN                        NaN
#
#                        iata_code                  local_code  \
# 0      #loc +airport +code +iata  #loc +airport +code +local
# 1                            LAX                         LAX
# 2                            ORD                         ORD
# 3                            JFK                         JFK
# 4                            ATL                         ATL
# ...                          ...                         ...
# 32003                        NaN                         NaN
# 32004                        NaN                        FD75
# 32005                        NaN                        0OH2
# 32006                        NaN                         NM1
# 32007                        NaN                         NaN
#
#                                                home_link  \
# 0                                    #meta +url +airport
# 1                                https://www.flylax.com/
# 2      https://www.flychicago.com/ohare/home/pages/de...
# 3                            https://www.jfkairport.com/
# 4                        http://www.atlanta-airport.com/
# ...                                                  ...
# 32003                                                NaN
# 32004                                                NaN
# 32005                                                NaN
# 32006                                                NaN
# 32007                                                NaN
#
#                                           wikipedia_link  \
# 0                                  #meta +url +wikipedia
# 1      https://en.wikipedia.org/wiki/Los_Angeles_Inte...
# 2      https://en.wikipedia.org/wiki/O'Hare_Internati...
# 3      https://en.wikipedia.org/wiki/John_F._Kennedy_...
# 4      https://en.wikipedia.org/wiki/Hartsfield–Jacks...
# ...                                                  ...
# 32003                                                NaN
# 32004                                                NaN
# 32005                                                NaN
# 32006                                                NaN
# 32007                                                NaN
#
#                                                 keywords         score  \
# 0                                        #meta +keywords  #meta +score
# 1                                            Tom Bradley       1335475
# 2                                     CHI, Orchard Place       1503175
# 3      Manhattan, New York City, NYC, Idlewild, IDL, ...       1052075
# 4                                                    NaN       2002475
# ...                                                  ...           ...
# 32003                                                NaN             0
# 32004              Florida Hospital Zephyrhills Heliport             0
# 32005                                                NaN             0
# 32006                                                NaN             0
# 32007                                                NaN             0
#
#                     last_updated
# 0                 #date +updated
# 1      2024-04-02T16:36:13+00:00
# 2      2024-03-09T23:28:49+00:00
# 3      2022-10-18T18:49:55+00:00
# 4      2024-04-02T16:26:01+00:00
# ...                          ...
# 32003  2021-03-30T13:04:34+00:00
# 32004  2021-06-11T17:55:06+00:00
# 32005  2017-09-09T20:04:27+00:00
# 32006  2018-05-15T23:12:01+00:00
# 32007  2020-09-28T10:17:31+00:00
#
# [32008 rows x 24 columns]

# %%
# Get unique values from 'type'
unique_values = Airports_df['type'].unique()

print(unique_values)
# Out:
# ['#loc +airport +type' 'large_airport' 'medium_airport' 'small_airport'
#  'closed' 'seaplane_base' 'heliport' 'balloonport']

# %%
#Keep only large_airport and medium_airport
filtered_airports_df = Airports_df[(Airports_df['type'] == 'large_airport')]
filtered_airports_df.head()
# Out:
#      id ident           type  \
# 1  3632  KLAX  large_airport
# 2  3754  KORD  large_airport
# 3  3622  KJFK  large_airport
# 4  3384  KATL  large_airport
# 5  3878  KSFO  large_airport
#
#                                                name latitude_deg  \
# 1                 Los Angeles International Airport    33.942501
# 2              Chicago O'Hare International Airport      41.9786
# 3              John F Kennedy International Airport    40.639447
# 4  Hartsfield Jackson Atlanta International Airport      33.6367
# 5               San Francisco International Airport    37.619806
#
#   longitude_deg elevation_ft continent   country_name iso_country  ...  \
# 1   -118.407997          125       NaN  United States          US  ...
# 2      -87.9048          680       NaN  United States          US  ...
# 3    -73.779317           13       NaN  United States          US  ...
# 4    -84.428101         1026       NaN  United States          US  ...
# 5   -122.374821           13       NaN  United States          US  ...
#
#   scheduled_service gps_code icao_code iata_code local_code  \
# 1                 1     KLAX      KLAX       LAX        LAX
# 2                 1     KORD      KORD       ORD        ORD
# 3                 1     KJFK      KJFK       JFK        JFK
# 4                 1     KATL      KATL       ATL        ATL
# 5                 1     KSFO      KSFO       SFO        SFO
#
#                                            home_link  \
# 1                            https://www.flylax.com/
# 2  https://www.flychicago.com/ohare/home/pages/de...
# 3                        https://www.jfkairport.com/
# 4                    http://www.atlanta-airport.com/
# 5                             http://www.flysfo.com/
#
#                                       wikipedia_link  \
# 1  https://en.wikipedia.org/wiki/Los_Angeles_Inte...
# 2  https://en.wikipedia.org/wiki/O'Hare_Internati...
# 3  https://en.wikipedia.org/wiki/John_F._Kennedy_...
# 4  https://en.wikipedia.org/wiki/Hartsfield–Jacks...
# 5  https://en.wikipedia.org/wiki/San_Francisco_In...
#
#                                             keywords    score  \
# 1                                        Tom Bradley  1335475
# 2                                 CHI, Orchard Place  1503175
# 3  Manhattan, New York City, NYC, Idlewild, IDL, ...  1052075
# 4                                                NaN  2002475
# 5                                           QSF, QBA  1112475
#
#                 last_updated
# 1  2024-04-02T16:36:13+00:00
# 2  2024-03-09T23:28:49+00:00
# 3  2022-10-18T18:49:55+00:00
# 4  2024-04-02T16:26:01+00:00
# 5  2024-04-02T16:43:50+00:00
#
# [5 rows x 24 columns]

# %%
filtered_airports_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 71 entries, 1 to 567
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 71 non-null     object
#  1   ident              71 non-null     object
#  2   type               71 non-null     object
#  3   name               71 non-null     object
#  4   latitude_deg       71 non-null     object
#  5   longitude_deg      71 non-null     object
#  6   elevation_ft       71 non-null     object
#  7   continent          0 non-null      object
#  8   country_name       71 non-null     object
#  9   iso_country        71 non-null     object
#  10  region_name        71 non-null     object
#  11  iso_region         71 non-null     object
#  12  local_region       71 non-null     object
#  13  municipality       71 non-null     object
#  14  scheduled_service  71 non-null     object
#  15  gps_code           71 non-null     object
#  16  icao_code          71 non-null     object
#  17  iata_code          71 non-null     object
#  18  local_code         71 non-null     object
#  19  home_link          68 non-null     object
#  20  wikipedia_link     71 non-null     object
#  21  keywords           29 non-null     object
#  22  score              71 non-null     object
#  23  last_updated       71 non-null     object
# dtypes: object(24)
# memory usage: 13.9+ KB

# %%
#Specify the columns to keep
columns_to_keep = ['name', 'iata_code']

# Create a new DataFrame with only the specified columns
airport_code_df = filtered_airports_df[columns_to_keep]

# Display the new DataFrame
airport_code_df
# Out:
#                                                  name iata_code
# 1                   Los Angeles International Airport       LAX
# 2                Chicago O'Hare International Airport       ORD
# 3                John F Kennedy International Airport       JFK
# 4    Hartsfield Jackson Atlanta International Airport       ATL
# 5                 San Francisco International Airport       SFO
# ..                                                ...       ...
# 85                        Tulsa International Airport       TUL
# 87                     Portland International Jetport       PWM
# 103          Sarasota Bradenton International Airport       SRQ
# 111             Orlando Sanford International Airport       SFB
# 567                                Joint Base Andrews       ADW
#
# [71 rows x 2 columns]

# %%
# Export the DataFrame to a CSV file
directory = 'Resources'
file_name = 'IATA_airports.csv'
file_path = os.path.join(directory, file_name)
airport_code_df.to_csv(file_path, index=False)

# %%
#Clean the Ratings file
# Read the CSV file
reviews_sample_df = pd.read_csv("Resources/AirlineReviews_ten_percent.csv")
#Kaggle site: https://www.kaggle.com/datasets/joelljungstrom/128k-airline-reviews - took 10% sample

reviews_sample_df=pd.DataFrame(reviews_sample_df)

# Display the first few rows
reviews_sample_df.head(100)
# Out:
#             Aircraft           AirlineName      CabinType       DateFlown  \
# 0                NaN       Delta Air Lines  Economy Class       June 2021
# 1   Boeing 777-300ER  Swiss Intl Air Lines  Economy Class        May 2019
# 2                NaN     American Airlines  Economy Class      April 2019
# 3                NaN               WOW air  Economy Class   February 2017
# 4                NaN         Kenya Airways  Economy Class  September 2019
# ..               ...                   ...            ...             ...
# 95               NaN      Virgin Australia  Economy Class             NaN
# 96               NaN       Libyan Airlines            NaN             NaN
# 97               NaN          LAN Airlines  Economy Class             NaN
# 98               NaN            Air France  Economy Class  September 2017
# 99    Boeing 737-800     American Airlines  Economy Class  September 2022
#
#                 DatePub  EntertainmentRating  FoodRating  GroundServiceRating  \
# 0        30th June 2021                    0           0                    1
# 1        14th June 2019                    5           5                    4
# 2       16th April 2019                    0           0                    2
# 3    27th February 2017                    2           2                    4
# 4     14th October 2019                    2           3                    1
# ..                  ...                  ...         ...                  ...
# 95    30th January 2013                    0           0                    0
# 96   9th September 2009                    0           0                    0
# 97    10th October 2013                    1           1                    0
# 98  17th September 2017                    0           3                    1
# 99     1st October 2022                    3           4                    4
#
#     OriginCountry  OverallScore  ...                                   Route  \
# 0    UnitedStates           1.0  ...                    Medford to Anchorage
# 1       Argentina           9.0  ...                     Sao Paulo to Zurich
# 2    UnitedStates           1.0  ...                 Little Rock to New York
# 3          Canada           8.0  ...        Bristol to Montréal via Keflavik
# 4    UnitedStates           1.0  ...                     Nairobi to New York
# ..            ...           ...  ...                                     ...
# 95      Australia           9.0  ...                                     NaN
# 96            NaN           4.0  ...                                     NaN
# 97  UnitedKingdom           5.0  ...                                     NaN
# 98   UnitedStates           1.0  ...                            Lyon to Rome
# 99   UnitedStates           7.0  ...  Cleveland to Orange County  via Dallas
#
#    SeatComfortRating ServiceRating                           Slug  \
# 0                  1             1                delta-air-lines
# 1                  5             5  swiss-international-air-lines
# 2                  2             2              american-airlines
# 3                  3             4                        wow-air
# 4                  1             1                  kenya-airways
# ..               ...           ...                            ...
# 95                 4             5               virgin-australia
# 96                 0             0                libyan-airlines
# 97                 2             1                   lan-airlines
# 98                 3             3                     air-france
# 99                 3             3              american-airlines
#
#                                     Title      TravelType   TripVerified  \
# 0   Delta’s customer service was horrible    Solo Leisure   Not Verified
# 1                     Outstanding service  Couple Leisure  Trip Verified
# 2    only cares about getting their money        Business   Not Verified
# 3                Thank you for everything    Solo Leisure            NaN
# 4              in-flight service was poor    Solo Leisure  Trip Verified
# ..                                    ...             ...            ...
# 95       Virgin Australia customer review             NaN            NaN
# 96        Libyan Airlines customer review             NaN            NaN
# 97           LAN Airlines customer review             NaN            NaN
# 98      have not received my lost baggage  Couple Leisure            NaN
# 99           flights were nice and smooth  Family Leisure  Trip Verified
#
#    ValueRating WifiRating                             unique_id
# 0            1          0  1823addc-1352-42ef-b059-b0284af628e0
# 1            5          0  d8b40dcd-2c67-46da-a35e-40cf6c3e0bcb
# 2            2          0  835c4a4c-550d-4366-b97d-1cf880c09a19
# 3            4          1  96c9c41c-228c-46df-a02d-d803ff52d998
# 4            1          0  cff00870-c1df-480a-8150-1a29a62c5b62
# ..         ...        ...                                   ...
# 95           5          0  df8b5bfb-e57b-49e1-b520-4f69542693c7
# 96           0          0  5d93c9db-18aa-46f7-8a62-1977e0096d0c
# 97           3          0  84190923-bc11-4d98-ac4c-9e47d3cd00c7
# 98           1          0  c50955ab-7f66-426a-8e9d-6f5b0aaedeef
# 99           3          2  db1784ca-543d-4689-86c2-2c4c28f1845b
#
# [100 rows x 22 columns]

# %%
# Get unique values of carriers
unique_values = reviews_sample_df['AirlineName'].unique()

print(unique_values)
# Out:
# ['Delta Air Lines' 'Swiss Intl Air Lines' 'American Airlines' 'WOW air'
#  'Kenya Airways' 'Malindo Air' 'United Airlines' 'Korean Air'
#  'China Southern Airlines' 'Myanmar Airways' 'IndiGo' 'British Airways'
#  'LAN Airlines' 'Norwegian' 'Wizz Air' 'Vueling Airlines'
#  'Turkish Airlines' 'Iran Air' 'LC Perú' 'FlySafair'
#  'Sun Country Airlines' 'Thomas Cook Airlines' 'Alaska Airlines'
#  'Icelandair' 'KLM Royal Dutch Airlines' 'Aeromexico' 'Southwest Airlines'
#  'Eurowings' 'Bangkok Airways' 'Etihad Airways' 'Hainan Airlines'
#  'Qantas Airways' 'Aircalin' 'Aer Lingus' 'Air Canada' 'Ryanair'
#  'WestJet Airlines' 'EVA Air' 'Sunwing Airlines' 'Garuda Indonesia'
#  'Juneyao Airlines' 'VietJet Air' 'Iberia' 'Spirit Airlines'
#  'Xiamen Airlines' 'Air Berlin' 'Aegean Airlines' 'Oman Air'
#  'Pegasus Airlines' 'Brussels Airlines' 'Allegiant Air' 'Virgin America'
#  'Asiana Airlines' 'easyJet' 'AirAsia' 'Air India' 'SriLankan Airlines'
#  'Thai Smile Airways' 'Corendon Airlines' 'Air Transat'
#  'Ukraine International' 'Monarch Airlines' 'Alitalia'
#  'Singapore Airlines' 'Virgin Australia' 'Libyan Airlines' 'Air France'
#  'Scoot' 'Japan Airlines' 'Air Canada rouge' 'LOT Polish Airlines'
#  'Jet Airways' 'Cape Air' 'Emirates' 'Thai Airways' 'Malaysia Airlines'
#  'Cathay Pacific Airways' 'American Eagle' 'Philippine Airlines'
#  'Insel Air' 'Darwin Airline' 'Qatar Airways' 'Air China'
#  'ANA All Nippon Airways' 'Jet2.com' 'Air New Zealand' 'Virgin Atlantic'
#  'Porter Airlines' 'Tigerair' 'Jetblue Airways' 'Rwandair'
#  'Kuwait Airways' 'AirAsia Philippines' 'Royal Air Maroc' 'LIAT'
#  'SpiceJet' 'Avianca' 'Bulgaria Air' 'BA CityFlyer' 'SAS Scandinavian'
#  'TAP Portugal' 'Level' 'Swoop' 'Gol Transportes Aéreos' 'Air Algerie'
#  'Cebu Pacific' 'Frontier Airlines' 'Aeroflot Russian Airlines' 'Interjet'
#  'Germanwings' 'Air Austral' 'Thomson Airways' 'Estonian Air' 'GoAir'
#  'Aerolineas Argentinas' 'Austrian Airlines' 'Gulf Air'
#  'Saudi Arabian Airlines' 'euroAtlantic Airways' 'US Airways'
#  'Jetstar Asia' 'China Eastern Airlines' 'ITA Airways' 'Lufthansa'
#  'SmartWings' 'Small Planet Airlines' 'TAM Airlines' 'XL Airways France'
#  'Finnair' 'PLAY' 'Vietnam Airlines' 'Flair Airlines' 'Berjaya Air'
#  'Sichuan Airlines' 'Air Serbia' 'Jazeera Airways' 'Comair'
#  'China Airlines' 'TAAG Angola Airlines' 'Volotea'
#  'Royal Jordanian Airlines' 'LATAM Airlines' 'Tigerair Australia'
#  'Royal Brunei Airlines' 'El Al Israel Airlines' 'AnadoluJet'
#  'Sky Airline' 'Transaero Airlines' 'VivaColombia' 'Egyptair'
#  'Cambodia Angkor Air' 'Sriwijaya Air' 'Middle East Airlines'
#  'La Compagnie' 'Jetstar Airways' 'Hawaiian Airlines' 'AirAsia India'
#  'Corsair' 'Air Italy' 'Titan Airways' 'VivaAerobús' 'Ethiopian Airlines'
#  'Copa Airlines' 'flydubai' 'Bassaka Air' 'CSA Czech Airlines' 'Arik Air'
#  'Silver Airways' 'Lynx Air' 'Croatia Airlines' 'Cayman Airways'
#  'Air Vanuatu' 'Air Europa' 'Olympic Air' 'SATA International'
#  'TACV Cabo Verde Airlines' 'TAROM Romanian' 'Condor Airlines'
#  'Air Tahiti Nui' 'Volaris' 'Transavia' 'Batik Air' 'SilkAir' 'Air Astana'
#  'Hong Kong Airlines' 'Martinair' 'South African Airways' 'Druk Air'
#  'BH Air' 'Meridiana' 'TUIfly' 'MIAT Mongolian Airlines'
#  'Air India Express' 'Spring Airlines' 'Blue Islands' 'Openskies'
#  'Mihin Lanka' 'Air Mauritius' 'Peruvian Airlines' 'SkyWest Airlines'
#  'Nok Air' 'Air Niugini' 'Belavia' 'Lao Skyway' 'Arkefly' 'Mahan Air'
#  'Bamboo Airways' 'Air Panama' 'Santa Barbara Airlines' 'SunExpress'
#  'Onur Air' 'Sky Express Airlines' 'QantasLink' 'Fiji Airways'
#  'SA Express' 'Air Arabia' 'Horizon Air' 'Jeju Air' 'AirAsia X'
#  'Uzbekistan Airways' 'CityJet' 'SATA Air Azores' 'Lion Air' 'TAME'
#  'Precision Air' 'Thai AirAsia' 'airBaltic' 'Air Malta' 'Iberia Express'
#  'flyadeal' 'Go First' 'Wingo' 'Nepal Airlines' 'Star Peru' 'Loganair'
#  'AirAsia Zest' 'Avelo Airlines' 'Mango Airlines' 'Cathay Dragon'
#  'Tianjin Airlines' 'Air Namibia' 'Vanilla Air' 'NIKI'
#  'Biman Bangladesh Airlines' 'Breeze Airways' 'TACA Airlines' 'Canaryfly'
#  'Vistara' 'Peach Aviation' 'Israir Airlines' 'Air Juan' 'Air Zimbabwe'
#  'SereneAir' 'VLM Airlines' 'Cubana Airlines' 'Caribbean Airlines'
#  'Air Greenland' 'Bhutan Airlines' 'Regional Express'
#  'Pakistan Intl Airlines' 'Adria Airways' 'Georgian Airways'
#  'Edelweiss Air' 'Boutique Air' 'Turkmenistan Airlines' 'Dragonair'
#  'Viva Air' 'airblue' 'Luxair' 'Blue1' 'Yangon Airways' 'Jetstar Pacific'
#  'Aero VIP' 'Azul Airlines' 'Air Cairo' 'Buta Airways' 'Rossiya Airlines'
#  'French Bee' 'Firefly' 'Citilink' 'Ultra Air' 'Blue Air' 'Thai Lion Air'
#  'Eastern Airways' 'Azerbaijan Airlines' 'HK Express' 'Air Madagascar'
#  'Salam Air' 'Air Memphis' 'Jetstar Japan' 'Tunisair' 'Atlasglobal'
#  'Bahamasair' 'SmartLynx Airlines' 'Air Koryo' 'V Air' 'TACA Regional'
#  'Wideroe' 'Kulula' 'Air Busan' 'Air Bagan' 'S7 Siberia Airlines'
#  'Thomas Cook Airlines Scandinavia' 'Airlink' 'Phuket Air' 'Air Botswana'
#  'Shanghai Airlines' 'Andes Líneas Aéreas' 'Hi Fly' 'Aurigny Air'
#  'Wamos Air' 'Atlantic Airways' 'Cobalt' 'Regent Airways' 'Aigle Azur'
#  'Air Corsica' 'TUI Airways' 'Arkia Israeli Airlines' 'Nauru Airlines'
#  'SyrianAir' 'Air Moldova' 'Island Air' 'Akasa Air'
#  'China United Airlines' 'InterSky' 'Nature Air' 'Shenzhen Airlines'
#  'LAN Peru' 'Sansa Airlines' 'Fly540.com' 'Blue Panorama Airlines'
#  'Air Macau' 'Airnorth' 'Rex Airlines' 'Air Caraibes' 'bmi Regional'
#  'Eastar Jet' 'Seaborne Airlines' 'Orient Thai Airlines' 'Ravn Alaska'
#  'Air Tanzania' 'Avianca Ecuador' 'FMI Air' 'Air Pegasus'
#  'Mandarin Airlines' 'Far Eastern Air Transport' 'PenAir' 'Amaszonas'
#  'LAM Mozambique' 'Iran Aseman Airlines' 'Kam Air' 'Laudamotion'
#  'Tame Línea Aérea Del Ecuador' 'Air Nostrum' 'Norse Atlantic Airways'
#  'Montenegro Airlines' 'Jetairfly' 'SkyWork Airlines' 'World2Fly' 'Joon'
#  'Karthago Airlines' 'Air Seychelles' 'Surinam Airways' 'FlyArystan'
#  'Aerosur' 'Privilege Style' 'Conviasa' 'Flynas' 'fastjet' 'ZIPAIR'
#  'Buddha Air' 'SVG Air' 'Suparna Airlines' 'Yemenia' 'Air Dolomiti'
#  'Smartavia' 'Thomas Cook Airlines Belgium' 'Mokulele Airlines'
#  'Qazaq Air' 'Malawian Airlines' 'Air Malawi' 'Skybus' 'Aeromar'
#  'Lubeck Air' 'Pobeda Airlines' 'Lao Airlines' 'Afriqiyah Airways'
#  'Utair Aviation' 'Omni Air International' 'Shandong Airlines' 'Wings Air'
#  'Tigerair Taiwan' 'Helvetic Airways' 'Skymark Airlines' 'TUS Airways'
#  'Freebird Airlines' 'Air Burkina' 'Mann Yadanarpon Airlines'
#  'Avior Airlines' 'Nordic Regional Airlines' 'StarFlyer' 'Cyprus Airways'
#  'Super Air Jet' 'Germania Airline' 'JetSmart' 'Yeti Airlines'
#  'Myanmar National Airlines' 'Solomon Airlines' 'Carpatair' 'Ellinair'
#  'Jin Air' 'Avianca Brazil' 'Primera Air' 'TAG Airlines' 'Lucky Air'
#  'Binter Canarias' 'Safi Airways' 'Shaheen Air' 'Passaredo']

# %%
#Take only data from the 9 airlines we're interested in
# List of carriers to keep
airlines_to_keep = ['American Airlines', 'Delta Air Lines', 'Spirit Airlines', 'Alaska Airlines', 'Southwest Airlines',
                   'Allegiant Air', 'Frontier Airlines', 'United Airlines', 'Jetblue Airways']

# Create a new DataFrame with only the specified airlines
reviews_sample_df2 = reviews_sample_df[reviews_sample_df['AirlineName'].isin(airlines_to_keep)]

# Display the new DataFrame
reviews_sample_df2.head()
# Out:
#    Aircraft        AirlineName      CabinType     DateFlown           DatePub  \
# 0       NaN    Delta Air Lines  Economy Class     June 2021    30th June 2021
# 2       NaN  American Airlines  Economy Class    April 2019   16th April 2019
# 6       NaN    United Airlines  Economy Class     July 2017     6th July 2017
# 7       NaN    United Airlines  Economy Class           NaN   24th April 2014
# 15      NaN    Delta Air Lines  Economy Class  January 2021  3rd January 2021
#
#     EntertainmentRating  FoodRating  GroundServiceRating OriginCountry  \
# 0                     0           0                    1  UnitedStates
# 2                     0           0                    2  UnitedStates
# 6                     0           0                    5  UnitedStates
# 7                     1           1                    0       Belgium
# 15                    1           0                    1  UnitedStates
#
#     OverallScore  ...                      Route SeatComfortRating  \
# 0            1.0  ...       Medford to Anchorage                 1
# 2            1.0  ...    Little Rock to New York                 2
# 6           10.0  ...         Houston to Calgary                 0
# 7            3.0  ...                        NaN                 2
# 15           2.0  ...  Boston to Los Angeles LAX                 3
#
#    ServiceRating               Slug  \
# 0              1    delta-air-lines
# 2              2  american-airlines
# 6              0    united-airlines
# 7              1    united-airlines
# 15             4    delta-air-lines
#
#                                          Title    TravelType  TripVerified  \
# 0        Delta’s customer service was horrible  Solo Leisure  Not Verified
# 2         only cares about getting their money      Business  Not Verified
# 6                 Very thankful for the agents  Solo Leisure           NaN
# 7              United Airlines customer review           NaN           NaN
# 15  I have been treated in such a horrible way      Business  Not Verified
#
#    ValueRating WifiRating                             unique_id
# 0            1          0  1823addc-1352-42ef-b059-b0284af628e0
# 2            2          0  835c4a4c-550d-4366-b97d-1cf880c09a19
# 6            5          0  388d55af-f557-497f-981a-9542366e211c
# 7            3          0  6038e580-88cc-406a-8258-1a31383b636c
# 15           2          0  8497d6c0-1aab-4c04-8e3c-9ce561cf6b64
#
# [5 rows x 22 columns]

# %%
reviews_sample_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2637 entries, 0 to 12945
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Aircraft             373 non-null    object
#  1   AirlineName          2637 non-null   object
#  2   CabinType            2527 non-null   object
#  3   DateFlown            2211 non-null   object
#  4   DatePub              2637 non-null   object
#  5   EntertainmentRating  2637 non-null   int64
#  6   FoodRating           2637 non-null   int64
#  7   GroundServiceRating  2637 non-null   int64
#  8   OriginCountry        2637 non-null   object
#  9   OverallScore         2581 non-null   float64
#  10  Recommended          2637 non-null   object
#  11  Review               2610 non-null   object
#  12  Route                2202 non-null   object
#  13  SeatComfortRating    2637 non-null   int64
#  14  ServiceRating        2637 non-null   int64
#  15  Slug                 2637 non-null   object
#  16  Title                2637 non-null   object
#  17  TravelType           2215 non-null   object
#  18  TripVerified         1625 non-null   object
#  19  ValueRating          2637 non-null   int64
#  20  WifiRating           2637 non-null   int64
#  21  unique_id            2637 non-null   object
# dtypes: float64(1), int64(7), object(14)
# memory usage: 473.8+ KB

# %%
# Get unique values from 'type'
unique_values = reviews_sample_df2['AirlineName'].unique()

print(unique_values)
# Out:
# ['Delta Air Lines' 'American Airlines' 'United Airlines' 'Alaska Airlines'
#  'Southwest Airlines' 'Spirit Airlines' 'Allegiant Air' 'Jetblue Airways'
#  'Frontier Airlines']

# %%
# Clean the DataFrame down to only the columns we need
# Specify the columns to keep
columns_to_keep = ['AirlineName', 'DateFlown','OriginCountry', 'CabinType', 'Recommended', 'Route', 'TravelType', 
                   'OverallScore', 'SeatComfortRating', 'EntertainmentRating', 'FoodRating', 'GroundServiceRating',
                    'ServiceRating', 'ValueRating', 'WifiRating']

# Create a new DataFrame with only the specified columns
reviews_sample_df3 = reviews_sample_df2[columns_to_keep]

# Sum all ratings excluding Overall Rating and place in a new column called Overall Score_Sum
# COMMENT THIS OUT BEFORE RUNNING CODE AGAIN
# reviews_sample_df3['OverallScore_Sum'] = reviews_sample_df3[['SeatComfortRating', 'EntertainmentRating', 'FoodRating', 'GroundServiceRating',
                                                        #'ServiceRating', 'ValueRating', 'WifiRating']].sum(axis = 1)

# Display the new DataFrame
reviews_sample_df3
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_16056\4153366952.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reviews_sample_df3['OverallScore_Sum'] = reviews_sample_df3[['SeatComfortRating', 'EntertainmentRating', 'FoodRating', 'GroundServiceRating',
#              AirlineName      DateFlown OriginCountry      CabinType  \
# 0        Delta Air Lines      June 2021  UnitedStates  Economy Class
# 2      American Airlines     April 2019  UnitedStates  Economy Class
# 6        United Airlines      July 2017  UnitedStates  Economy Class
# 7        United Airlines            NaN       Belgium  Economy Class
# 15       Delta Air Lines   January 2021  UnitedStates  Economy Class
# ...                  ...            ...           ...            ...
# 12921    Delta Air Lines      June 2016  UnitedStates  Economy Class
# 12930    Delta Air Lines     April 2021  UnitedStates  Economy Class
# 12941    Jetblue Airways       May 2022  UnitedStates  Economy Class
# 12942    United Airlines       May 2018  UnitedStates  Economy Class
# 12945  American Airlines  February 2022  UnitedStates  Economy Class
#
#       Recommended                              Route      TravelType  \
# 0              no               Medford to Anchorage    Solo Leisure
# 2              no            Little Rock to New York        Business
# 6             yes                 Houston to Calgary    Solo Leisure
# 7              no                                NaN             NaN
# 15             no          Boston to Los Angeles LAX        Business
# ...           ...                                ...             ...
# 12921          no                 LAS to PDX via LAX    Solo Leisure
# 12930          no              Albany to Kansas City    Solo Leisure
# 12941          no            Los Angeles to Richmond  Family Leisure
# 12942          no  Nashville to Honolulu via Houston  Family Leisure
# 12945          no              Tallahassee to Miami   Family Leisure
#
#        OverallScore  SeatComfortRating  EntertainmentRating  FoodRating  \
# 0               1.0                  1                    0           0
# 2               1.0                  2                    0           0
# 6              10.0                  0                    0           0
# 7               3.0                  2                    1           1
# 15              2.0                  3                    1           0
# ...             ...                ...                  ...         ...
# 12921           3.0                  3                    0           0
# 12930           1.0                  1                    1           1
# 12941           1.0                  1                    0           0
# 12942           1.0                  1                    1           2
# 12945           1.0                  1                    0           0
#
#        GroundServiceRating  ServiceRating  ValueRating  WifiRating  \
# 0                        1              1            1           0
# 2                        2              2            2           0
# 6                        5              0            5           0
# 7                        0              1            3           0
# 15                       1              4            2           0
# ...                    ...            ...          ...         ...
# 12921                    1              4            3           0
# 12930                    1              1            1           1
# 12941                    1              1            1           0
# 12942                    1              2            1           1
# 12945                    1              1            1           0
#
#        OverallScore_Sum
# 0                     4
# 2                     8
# 6                    10
# 7                     8
# 15                   11
# ...                 ...
# 12921                11
# 12930                 7
# 12941                 4
# 12942                 9
# 12945                 4
#
# [2637 rows x 16 columns]

# %%
# Get unique values from 'type'
unique_values = reviews_sample_df3['OriginCountry'].unique()

print(unique_values)
# Out:
# ['UnitedStates' 'Belgium' 'Canada' 'UnitedKingdom' 'Australia'
#  'SouthAfrica' 'USVirginIslands' 'PuertoRico' 'Japan' 'Taiwan' 'Malaysia'
#  'Singapore' 'Argentina' 'Switzerland' 'Brazil' 'CostaRica' 'Ireland'
#  'CaymanIslands' 'Sweden' 'India' 'Norway' 'Georgia' 'Germany' 'Austria'
#  'Azerbaijan' 'Netherlands' 'Thailand' 'TrinidadTobago' 'Nicaragua'
#  'Colombia' 'Bahamas' 'SouthKorea' 'France' 'NewZealand' 'Qatar'
#  'HongKong' 'China' 'Ecuador' 'Italy' 'Albania' 'UnitedArabEmirates'
#  'Israel' 'Jamaica' 'Greece' 'Turkey' 'CzechRepublic' 'Lithuania'
#  'Denmark' 'Indonesia' 'Guatemala' 'Philippines' 'Bermuda' 'Algeria'
#  'Poland' 'Spain' 'Kuwait']

# %%
#Only flights originating from the US
countries_to_keep = ['UnitedStates']

# Create a new DataFrame with only the specified airlines
reviews_sample_df3 = reviews_sample_df3[reviews_sample_df3['OriginCountry'].isin(countries_to_keep)]

# Display the new DataFrame
reviews_sample_df3
# Out:
#              AirlineName      DateFlown OriginCountry      CabinType  \
# 0        Delta Air Lines      June 2021  UnitedStates  Economy Class
# 2      American Airlines     April 2019  UnitedStates  Economy Class
# 6        United Airlines      July 2017  UnitedStates  Economy Class
# 15       Delta Air Lines   January 2021  UnitedStates  Economy Class
# 27       Alaska Airlines            NaN  UnitedStates  Economy Class
# ...                  ...            ...           ...            ...
# 12921    Delta Air Lines      June 2016  UnitedStates  Economy Class
# 12930    Delta Air Lines     April 2021  UnitedStates  Economy Class
# 12941    Jetblue Airways       May 2022  UnitedStates  Economy Class
# 12942    United Airlines       May 2018  UnitedStates  Economy Class
# 12945  American Airlines  February 2022  UnitedStates  Economy Class
#
#       Recommended                              Route      TravelType  \
# 0              no               Medford to Anchorage    Solo Leisure
# 2              no            Little Rock to New York        Business
# 6             yes                 Houston to Calgary    Solo Leisure
# 15             no          Boston to Los Angeles LAX        Business
# 27            yes                                NaN             NaN
# ...           ...                                ...             ...
# 12921          no                 LAS to PDX via LAX    Solo Leisure
# 12930          no              Albany to Kansas City    Solo Leisure
# 12941          no            Los Angeles to Richmond  Family Leisure
# 12942          no  Nashville to Honolulu via Houston  Family Leisure
# 12945          no              Tallahassee to Miami   Family Leisure
#
#        OverallScore  SeatComfortRating  EntertainmentRating  FoodRating  \
# 0               1.0                  1                    0           0
# 2               1.0                  2                    0           0
# 6              10.0                  0                    0           0
# 15              2.0                  3                    1           0
# 27             10.0                  4                    0           5
# ...             ...                ...                  ...         ...
# 12921           3.0                  3                    0           0
# 12930           1.0                  1                    1           1
# 12941           1.0                  1                    0           0
# 12942           1.0                  1                    1           2
# 12945           1.0                  1                    0           0
#
#        GroundServiceRating  ServiceRating  ValueRating  WifiRating  \
# 0                        1              1            1           0
# 2                        2              2            2           0
# 6                        5              0            5           0
# 15                       1              4            2           0
# 27                       0              5            5           0
# ...                    ...            ...          ...         ...
# 12921                    1              4            3           0
# 12930                    1              1            1           1
# 12941                    1              1            1           0
# 12942                    1              2            1           1
# 12945                    1              1            1           0
#
#        OverallScore_Sum
# 0                     4
# 2                     8
# 6                    10
# 15                   11
# 27                   19
# ...                 ...
# 12921                11
# 12930                 7
# 12941                 4
# 12942                 9
# 12945                 4
#
# [2312 rows x 16 columns]

# %%
# Calculate the average score grouped by AirlineName
average_scores = reviews_sample_df3.groupby('AirlineName')[['OverallScore', 'SeatComfortRating', 'EntertainmentRating',
                                            'FoodRating', 'GroundServiceRating', 'ServiceRating', 'ValueRating', 'WifiRating']].mean().reset_index()

# Rename the columns for clarity (optional)
average_scores.columns = ['AirlineName', 'Avg_OverallScore', 'Avg_SeatComfortRating', 'Avg_EntertainmentRating', 
                          'Avg_FoodRating', 'Avg_GroundServiceRating', 'Avg_ServiceRating', ' Avg_ValueRating', 'Avg_WifiRating']


# Display the new DataFrame
Airline_reviews_df = pd.DataFrame(average_scores)
Airline_reviews_df = Airline_reviews_df.round(2)
Airline_reviews_df
# Out:
#           AirlineName  Avg_OverallScore  Avg_SeatComfortRating  \
# 0     Alaska Airlines              3.43                   2.19
# 1       Allegiant Air              2.42                   1.78
# 2   American Airlines              2.41                   1.96
# 3     Delta Air Lines              3.39                   2.35
# 4   Frontier Airlines              1.63                   1.34
# 5     Jetblue Airways              3.21                   2.35
# 6  Southwest Airlines              4.12                   2.27
# 7     Spirit Airlines              2.22                   1.47
# 8     United Airlines              2.57                   1.96
#
#    Avg_EntertainmentRating  Avg_FoodRating  Avg_GroundServiceRating  \
# 0                     1.09            1.53                     1.56
# 1                     0.49            0.88                     1.28
# 2                     1.19            1.34                     1.52
# 3                     1.76            1.76                     1.86
# 4                     0.51            0.64                     1.11
# 5                     1.74            1.74                     1.66
# 6                     0.84            1.74                     1.83
# 7                     0.52            0.81                     1.21
# 8                     1.34            1.42                     1.55
#
#    Avg_ServiceRating   Avg_ValueRating  Avg_WifiRating
# 0               2.29              2.06            0.74
# 1               1.92              1.85            0.25
# 2               2.04              1.68            0.91
# 3               2.66              2.05            0.95
# 4               1.57              1.40            0.28
# 5               2.33              2.08            1.26
# 6               2.78              2.48            0.94
# 7               1.80              1.68            0.28
# 8               2.21              1.75            0.92

# %%
# Export the DataFrame to a CSV file
directory = 'Resources'
file_name = 'Airline_reviews.csv'
file_path = os.path.join(directory, file_name)
Airline_reviews_df.to_csv(file_path, index=False)

# %% [markdown]
# # SQL Alchemy

# %%
# Import SQL Alchemy for connecting to DBs
from sqlalchemy import create_engine, inspect

# Import and establish Base for which classes will be constructed
from sqlalchemy.orm import declarative_base
Base = declarative_base()

# Import modules to declare columns and data types
from sqlalchemy import Column, Integer, String, Float, ForeignKey, func

# %%
# Create DB Engine
engine = create_engine("sqlite:///flights.db")

# %%
# Create a Session Object to Connect to DB
from sqlalchemy.orm import Session
session = Session(bind=engine)
session

# %%
#Reset the entire database if adding more columns
Base.metadata.drop_all(engine)
Base.metadata.clear()

# %%
# Create an Airline Class
class Airline(Base):
    __tablename__ = 'airlines'
    IATA_code = Column(String(3), primary_key=True)
    Airline = Column(String(30))

# Create an Airport Class
class Airport(Base):
    __tablename__ = 'airports'
    iata_code = Column(String(3), primary_key=True)
    name = Column(String(30))

# Create an Airline Rating Class
class AirlineRating(Base):
    __tablename__ = 'airline_rating'
    AirlineName = Column(String(30), primary_key=True)
    Avg_OverallScore = Column(Float)
    Avg_SeatComfortRating = Column(Float)
    Avg_EntertainmentRating = Column(Float)
    Avg_FoodRating = Column(Float)
    Avg_GroundServiceRating = Column(Float)
    Avg_ServiceRating = Column(Float)
    Avg_ValueRating = Column(Float)	
    Avg_WifiRating = Column(Float)

# Create an Flight Data Class
class FlightData(Base):
    __tablename__ = 'flight_data'
    id = Column(Integer, primary_key=True)
    FL_DATE = Column(String(30))
    OP_CARRIER = Column(String(2), ForeignKey('airlines.IATA_code'))
    OP_CARRIER_FL_NUM = Column(Integer)
    ORIGIN = Column(String(3), ForeignKey('airports.iata_code'))
    DEST = Column(String(3), ForeignKey('airports.iata_code'))
    CRS_DEP_TIME = Column(Integer)
    DEP_TIME = Column(Float)
    DEP_DELAY = Column(Float)
    CRS_ARR_TIME = Column(Integer)
    ARR_TIME = Column(Float)
    CANCELLED = Column(Float)
    AIR_TIME = Column(Float)
    DISTANCE = Column(Float)

# Create tables
Base.metadata.create_all(engine)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_16056\2262358420.py:2: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.Airline, and will be replaced in the string-lookup table.
#   class Airline(Base):
# C:\Users\chris\AppData\Local\Temp\ipykernel_16056\2262358420.py:8: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.Airport, and will be replaced in the string-lookup table.
#   class Airport(Base):
# C:\Users\chris\AppData\Local\Temp\ipykernel_16056\2262358420.py:14: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.AirlineRating, and will be replaced in the string-lookup table.
#   class AirlineRating(Base):
# C:\Users\chris\AppData\Local\Temp\ipykernel_16056\2262358420.py:27: SAWarning: This declarative base already contains a class with the same class name and module name as __main__.FlightData, and will be replaced in the string-lookup table.
#   class FlightData(Base):

# %%
# Get the table names using
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['airline_rating', 'airlines', 'airports', 'flight_data']

# %%
# Get a list of column names and types
columns = inspector.get_columns('airlines')
for c in columns:
    print(c['name'], c["type"])
# Out:
# IATA_code VARCHAR(3)
# Airline VARCHAR(30)

# %%
# Get a list of column names and types
columns = inspector.get_columns('airports')
for c in columns:
    print(c['name'], c["type"])
# Out:
# iata_code VARCHAR(3)
# name VARCHAR(30)

# %%
# Get a list of column names and types
columns = inspector.get_columns('airline_rating')
for c in columns:
    print(c['name'], c["type"])
# Out:
# AirlineName VARCHAR(30)
# Avg_OverallScore FLOAT
# Avg_SeatComfortRating FLOAT
# Avg_EntertainmentRating FLOAT
# Avg_FoodRating FLOAT
# Avg_GroundServiceRating FLOAT
# Avg_ServiceRating FLOAT
# Avg_ValueRating FLOAT
# Avg_WifiRating FLOAT

# %%
# Get a list of column names and types
columns = inspector.get_columns('flight_data')
for c in columns:
    print(c['name'], c["type"])
# Out:
# id INTEGER
# FL_DATE VARCHAR(30)
# OP_CARRIER VARCHAR(2)
# OP_CARRIER_FL_NUM INTEGER
# ORIGIN VARCHAR(3)
# DEST VARCHAR(3)
# CRS_DEP_TIME INTEGER
# DEP_TIME FLOAT
# DEP_DELAY FLOAT
# CRS_ARR_TIME INTEGER
# ARR_TIME FLOAT
# CANCELLED FLOAT
# AIR_TIME FLOAT
# DISTANCE FLOAT

# %%
# Load existing data into flight data
Main_df3.to_sql('flight_data', con=engine, if_exists='append', index=False)
# Out:
# 47717

# %%
# Return first 10 rows
query_flight = """
SELECT *
FROM flight_data f
LIMIT 10
"""

flight_data_df = pd.read_sql(query_flight, con=engine)
print(flight_data_df)
# Out:
#    id     FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  CRS_DEP_TIME  \
# 0   1  2018-11-09         DL               2602    ATL  MDT          2132
# 1   2  2018-11-30         AS                112    ANC  SEA           800
# 2   3  2018-08-04         WN               5855    MSY  MCO          1635
# 3   4  2018-03-12         AS                445    LAX  SEA          1840
# 4   5  2018-01-28         WN               2674    PHX  ABQ          1255
# 5   6  2018-11-27         UA               1891    DTW  ORD           748
# 6   7  2018-08-01         UA               2391    EWR  SLC          1955
# 7   8  2018-10-16         WN                874    MAF  HOU          1800
# 8   9  2018-01-19         B6               1443    EWR  PBI          2100
# 9  10  2018-07-21         AA               1789    BUF  CLT           823
#
#    DEP_TIME  DEP_DELAY  CRS_ARR_TIME  ARR_TIME  CANCELLED  AIR_TIME  DISTANCE
# 0    2144.0       12.0          2330    2328.0        0.0      84.0     620.0
# 1     759.0       -1.0          1228    1250.0        0.0     199.0    1448.0
# 2    1629.0       -6.0          1920    1908.0        0.0      79.0     551.0
# 3    1854.0       14.0          2132    2138.0        0.0     120.0     954.0
# 4    1252.0       -3.0          1400    1355.0        0.0      50.0     328.0
# 5     747.0       -1.0           809     850.0        0.0      46.0     235.0
# 6    1054.0      899.0          2308    1326.0        0.0     256.0    1969.0
# 7    2013.0      133.0          1920    2126.0        0.0      63.0     441.0
# 8    2125.0       25.0          2355    2400.0        0.0     133.0    1023.0
# 9     819.0       -4.0          1021    1015.0        0.0      85.0     546.0

# %%
# Load existing data into airline_rating
Airline_reviews_df.to_sql('airline_rating', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:938, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     937 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 938     cursor.executemany(statement, parameters)
#
# OperationalError: table airline_rating has no column named  Avg_ValueRating
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# Cell In[230], line 2
#       1 # Load existing data into airline_rating
# ----> 2 Airline_reviews_df.to_sql('airline_rating', con=engine, if_exists='append', index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2018, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
#    2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    (...)
#    2015     dtype=dtype,
#    2016 )
# -> 2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    2021     frame=frame,
#    2022     name=name,
#    2023     index=index,
#    2024     schema=schema,
#    2025     chunksize=chunksize,
#    2026     method=method,
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#    2031 return total_inserted
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1567, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1565 if re.search(msg, err_text):
#    1566     raise ValueError("inf cannot be used with MySQL") from err
# -> 1567 raise err
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1558, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1555 from sqlalchemy import exc
#    1557 try:
# -> 1558     return table.insert(chunksize=chunksize, method=method)
#    1559 except exc.StatementError as err:
#    1560     # GH34431
#    1561     # https://stackoverflow.com/a/67358288/6067848
#    1562     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1563     )|inf can not be used with MySQL"""
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1119, in SQLTable.insert(self, chunksize, method)
#    1116     break
#    1118 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120 # GH 46891
#    1121 if num_inserted is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)
#    1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1934                 break
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#    1943     if self.dialect._has_events:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:938, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     937 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 938     cursor.executemany(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) table airline_rating has no column named  Avg_ValueRating
# [SQL: INSERT INTO airline_rating ("AirlineName", "Avg_OverallScore", "Avg_SeatComfortRating", "Avg_EntertainmentRating", "Avg_FoodRating", "Avg_GroundServiceRating", "Avg_ServiceRating", " Avg_ValueRating", "Avg_WifiRating") VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?)]
# [parameters: [('Alaska Airlines', 3.43, 2.19, 1.09, 1.53, 1.56, 2.29, 2.06, 0.74), ('Allegiant Air', 2.42, 1.78, 0.49, 0.88, 1.28, 1.92, 1.85, 0.25), ('American Airlines', 2.41, 1.96, 1.19, 1.34, 1.52, 2.04, 1.68, 0.91), ('Delta Air Lines', 3.39, 2.35, 1.76, 1.76, 1.86, 2.66, 2.05, 0.95), ('Frontier Airlines', 1.63, 1.34, 0.51, 0.64, 1.11, 1.57, 1.4, 0.28), ('Jetblue Airways', 3.21, 2.35, 1.74, 1.74, 1.66, 2.33, 2.08, 1.26), ('Southwest Airlines', 4.12, 2.27, 0.84, 1.74, 1.83, 2.78, 2.48, 0.94), ('Spirit Airlines', 2.22, 1.47, 0.52, 0.81, 1.21, 1.8, 1.68, 0.28), ('United Airlines', 2.57, 1.96, 1.34, 1.42, 1.55, 2.21, 1.75, 0.92)]]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# Return first 10 rows
query_airline = """
SELECT *
FROM airline_rating ar
LIMIT 10
"""

airline_rating_df = pd.read_sql(query_airline, con=engine)
print(airline_rating_df)
# Out:
# Empty DataFrame
# Columns: [AirlineName, Avg_OverallScore, Avg_SeatComfortRating, Avg_EntertainmentRating, Avg_FoodRating, Avg_GroundServiceRating, Avg_ServiceRating, Avg_ValueRating, Avg_WifiRating]
# Index: []

# %%
# Load existing data into airports
airport_code_df.to_sql('airports', con=engine, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:938, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     937 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 938     cursor.executemany(statement, parameters)
#
# IntegrityError: UNIQUE constraint failed: airports.iata_code
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[194], line 2
#       1 # Load existing data into airports
# ----> 2 airport_code_df.to_sql('airports', con=engine, if_exists='append', index=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:3087, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2889 """
#    2890 Write records stored in a DataFrame to a SQL database.
#    2891
#    (...)
#    3083 [(1,), (None,), (2,)]
#    3084 """  # noqa: E501
#    3085 from pandas.io import sql
# -> 3087 return sql.to_sql(
#    3088     self,
#    3089     name,
#    3090     con,
#    3091     schema=schema,
#    3092     if_exists=if_exists,
#    3093     index=index,
#    3094     index_label=index_label,
#    3095     chunksize=chunksize,
#    3096     dtype=dtype,
#    3097     method=method,
#    3098 )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:842, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     837     raise NotImplementedError(
#     838         "'frame' argument should be either a Series or a DataFrame"
#     839     )
#     841 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 842     return pandas_sql.to_sql(
#     843         frame,
#     844         name,
#     845         if_exists=if_exists,
#     846         index=index,
#     847         index_label=index_label,
#     848         schema=schema,
#     849         chunksize=chunksize,
#     850         dtype=dtype,
#     851         method=method,
#     852         engine=engine,
#     853         **engine_kwargs,
#     854     )
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:2018, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2006 sql_engine = get_engine(engine)
#    2008 table = self.prep_table(
#    2009     frame=frame,
#    2010     name=name,
#    (...)
#    2015     dtype=dtype,
#    2016 )
# -> 2018 total_inserted = sql_engine.insert_records(
#    2019     table=table,
#    2020     con=self.con,
#    2021     frame=frame,
#    2022     name=name,
#    2023     index=index,
#    2024     schema=schema,
#    2025     chunksize=chunksize,
#    2026     method=method,
#    2027     **engine_kwargs,
#    2028 )
#    2030 self.check_case_sensitive(name=name, schema=schema)
#    2031 return total_inserted
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1567, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1565 if re.search(msg, err_text):
#    1566     raise ValueError("inf cannot be used with MySQL") from err
# -> 1567 raise err
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1558, in SQLAlchemyEngine.insert_records(self, table, con, frame, name, index, schema, chunksize, method, **engine_kwargs)
#    1555 from sqlalchemy import exc
#    1557 try:
# -> 1558     return table.insert(chunksize=chunksize, method=method)
#    1559 except exc.StatementError as err:
#    1560     # GH34431
#    1561     # https://stackoverflow.com/a/67358288/6067848
#    1562     msg = r"""(\(1054, "Unknown column 'inf(e0)?' in 'field list'"\))(?#
#    1563     )|inf can not be used with MySQL"""
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1119, in SQLTable.insert(self, chunksize, method)
#    1116     break
#    1118 chunk_iter = zip(*(arr[start_i:end_i] for arr in data_list))
# -> 1119 num_inserted = exec_insert(conn, keys, chunk_iter)
#    1120 # GH 46891
#    1121 if num_inserted is not None:
#
# File ~\anaconda3\Lib\site-packages\pandas\io\sql.py:1010, in SQLTable._execute_insert(self, conn, keys, data_iter)
#     998 """
#     999 Execute SQL statement inserting data
#    1000
#    (...)
#    1007    Each item contains a list of values to be inserted
#    1008 """
#    1009 data = [dict(zip(keys, row)) for row in data_iter]
# -> 1010 result = conn.execute(self.table.insert(), data)
#    1011 return result.rowcount
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1416     raise exc.ObjectNotExecutableError(statement) from err
#    1417 else:
# -> 1418     return meth(
#    1419         self,
#    1420         distilled_parameters,
#    1421         execution_options or NO_OPTIONS,
#    1422     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\sql\elements.py:515, in ClauseElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     513     if TYPE_CHECKING:
#     514         assert isinstance(self, Executable)
# --> 515     return connection._execute_clauseelement(
#     516         self, distilled_params, execution_options
#     517     )
#     518 else:
#     519     raise exc.ObjectNotExecutableError(self)
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1640, in Connection._execute_clauseelement(self, elem, distilled_parameters, execution_options)
#    1628 compiled_cache: Optional[CompiledCacheType] = execution_options.get(
#    1629     "compiled_cache", self.engine._compiled_cache
#    1630 )
#    1632 compiled_sql, extracted_params, cache_hit = elem._compile_w_cache(
#    1633     dialect=dialect,
#    1634     compiled_cache=compiled_cache,
#    (...)
#    1638     linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1639 )
# -> 1640 ret = self._execute_context(
#    1641     dialect,
#    1642     dialect.execution_ctx_cls._init_compiled,
#    1643     compiled_sql,
#    1644     distilled_parameters,
#    1645     execution_options,
#    1646     compiled_sql,
#    1647     distilled_parameters,
#    1648     elem,
#    1649     extracted_params,
#    1650     cache_hit=cache_hit,
#    1651 )
#    1652 if has_events:
#    1653     self.dispatch.after_execute(
#    1654         self,
#    1655         elem,
#    (...)
#    1659         ret,
#    1660     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1846, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1844     return self._exec_insertmany_context(dialect, context)
#    1845 else:
# -> 1846     return self._exec_single_context(
#    1847         dialect, context, statement, parameters
#    1848     )
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1986, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1983     result = context._setup_result_proxy()
#    1985 except BaseException as e:
# -> 1986     self._handle_dbapi_exception(
#    1987         e, str_statement, effective_parameters, cursor, context
#    1988     )
#    1990 return result
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:2355, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2353 elif should_wrap:
#    2354     assert sqlalchemy_exception is not None
# -> 2355     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2356 else:
#    2357     assert exc_info[1] is not None
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\base.py:1936, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1934                 break
#    1935     if not evt_handled:
# -> 1936         self.dialect.do_executemany(
#    1937             cursor,
#    1938             str_statement,
#    1939             effective_parameters,
#    1940             context,
#    1941         )
#    1942 elif not effective_parameters and context.no_parameters:
#    1943     if self.dialect._has_events:
#
# File ~\anaconda3\Lib\site-packages\sqlalchemy\engine\default.py:938, in DefaultDialect.do_executemany(self, cursor, statement, parameters, context)
#     937 def do_executemany(self, cursor, statement, parameters, context=None):
# --> 938     cursor.executemany(statement, parameters)
#
# IntegrityError: (sqlite3.IntegrityError) UNIQUE constraint failed: airports.iata_code
# [SQL: INSERT INTO airports (name, iata_code) VALUES (?, ?)]
# [parameters: [('Los Angeles International Airport', 'LAX'), ("Chicago O'Hare International Airport", 'ORD'), ('John F Kennedy International Airport', 'JFK'), ('Hartsfield Jackson Atlanta International Airport', 'ATL'), ('San Francisco International Airport', 'SFO'), ('Newark Liberty International Airport', 'EWR'), ('Dallas Fort Worth International Airport', 'DFW'), ('Harry Reid International Airport', 'LAS')  ... displaying 10 of 71 total bound parameter sets ...  ('Orlando Sanford International Airport', 'SFB'), ('Joint Base Andrews', 'ADW')]]
# (Background on this error at: https://sqlalche.me/e/20/gkpj)

# %%
# Return first 10 rows
query_airport = """
SELECT *
FROM airports a
LIMIT 10
"""

airport_df = pd.read_sql(query_airport, con=engine)
print(airport_df)
# Out:
#   iata_code                                              name
# 0       LAX                 Los Angeles International Airport
# 1       ORD              Chicago O'Hare International Airport
# 2       JFK              John F Kennedy International Airport
# 3       ATL  Hartsfield Jackson Atlanta International Airport
# 4       SFO               San Francisco International Airport
# 5       EWR              Newark Liberty International Airport
# 6       DFW           Dallas Fort Worth International Airport
# 7       LAS                  Harry Reid International Airport
# 8       MCO                     Orlando International Airport
# 9       DEN                      Denver International Airport

# %%
# Load existing data into airlines
IATA_df.to_sql('airlines', con=engine, if_exists='append', index=False)
# Out:
# 9

# %%
# Return first 10 rows
query_airline = """
SELECT *
FROM airlines ai
LIMIT 10
"""

airline_df = pd.read_sql(query_airport, con=engine)
print(airline_df)
# Out:
#   iata_code                                              name
# 0       LAX                 Los Angeles International Airport
# 1       ORD              Chicago O'Hare International Airport
# 2       JFK              John F Kennedy International Airport
# 3       ATL  Hartsfield Jackson Atlanta International Airport
# 4       SFO               San Francisco International Airport
# 5       EWR              Newark Liberty International Airport
# 6       DFW           Dallas Fort Worth International Airport
# 7       LAS                  Harry Reid International Airport
# 8       MCO                     Orlando International Airport
# 9       DEN                      Denver International Airport

# %%
print(session.query(Airline).first())
print(session.query(AirlineRating).first())
print(session.query(Airport).first())
print(session.query(FlightData).first())
# Out:
# None
# None
# None
# <__main__.FlightData object at 0x0000028F9E0A4320>

# %%
# Store the query in a variable
query = session.query(
    FlightData.FL_DATE,
    FlightData.OP_CARRIER,
    Airline.Airline.label('AirlineName'),
    AirlineRating.Avg_OverallScore,
    FlightData.ORIGIN,
    Airport.name.label("OriginAirport"),
    FlightData.DEST,
    FlightData.DISTANCE,
    FlightData.DEP_DELAY,
    FlightData.CANCELLED
).join(
    Airline, FlightData.OP_CARRIER == Airline.IATA_code
).join(
    AirlineRating, Airline.Airline == AirlineRating.AirlineName
).join(
    Airport, FlightData.ORIGIN == Airport.iata_code
)

# Now execute it later
results = query.all()

df = pd.DataFrame(results, columns=[
    'FL_DATE', 'OP_CARRIER', 'AirlineName', 'Avg_OverallScore',
    'ORIGIN', 'OriginAirport', 'DEST', 'DISTANCE', 'DEP_DELAY', 'CANCELLED'
])

df
# Out:
# Empty DataFrame
# Columns: [FL_DATE, OP_CARRIER, AirlineName, Avg_OverallScore, ORIGIN, OriginAirport, DEST, DISTANCE, DEP_DELAY, CANCELLED]
# Index: []
